# %%
import numpy as np
import pandas as pd
import lightgbm as lgb
import optuna
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler

# %%
# 데이터 불러오기 및 전처리
df = pd.read_csv('train.csv')
df = df.drop('ID', axis=1)

# %%
# 결측치 처리 및 특성 엔지니어링
fill_cols = ['F04', 'F11', 'F18', 'F19', 'F24', 'F27', 'F29', 'F32', 'F33', 'F36', 'F38']
df[fill_cols] = df[fill_cols].fillna(0)
df = df.fillna('NAN')
float_columns = df.select_dtypes(include=['float64']).columns
df[float_columns] = df[float_columns].astype('int64')
object_columns = df.select_dtypes(include=['object']).columns
df[object_columns] = df[object_columns].astype('category')

# %%
# 표준화
scaler = StandardScaler()
scaled_features = scaler.fit_transform(df.drop('Click', axis=1).select_dtypes(include=[np.number]))
scaled_df = pd.DataFrame(scaled_features, columns=df.drop('Click', axis=1).select_dtypes(include=[np.number]).columns)
df.update(scaled_df)

# %%
# 범주형 피처를 학습 데이터에서 가져옴
cat_features = list(object_columns)

# %%
# Optuna 목적 함수 정의
def objective(trial):
    # K-폴드 교차 검증 설정
    kf = KFold(n_splits=5, shuffle=True, random_state=42)
    aucs = []
    
    for train_idx, valid_idx in kf.split(df):
        train_x, valid_x = df.iloc[train_idx].drop('Click', axis=1), df.iloc[valid_idx].drop('Click', axis=1)
        train_y, valid_y = df.iloc[train_idx]['Click'], df.iloc[valid_idx]['Click']
        
        param = {
            'objective': 'binary',
            'metric': 'auc',
            'verbosity': -1,
            'boosting_type': 'gbdt',
            'num_leaves': trial.suggest_int('num_leaves', 20, 200),
            'max_depth': trial.suggest_int('max_depth', 3, 15),
            'learning_rate': trial.suggest_float('learning_rate', 1e-4, 1e-1, log=True),
            'feature_fraction': trial.suggest_float('feature_fraction', 0.6, 1.0),
            'bagging_fraction': trial.suggest_float('bagging_fraction', 0.6, 1.0),
            'bagging_freq': trial.suggest_int('bagging_freq', 1, 7),
            'min_child_samples': trial.suggest_int('min_child_samples', 5, 100),
        }
        
        model = lgb.LGBMClassifier(**param)
        model.fit(
            train_x, train_y,
            eval_set=[(valid_x, valid_y)],
            eval_metric='auc',
            callbacks=[lgb.early_stopping(stopping_rounds=100, verbose=False)],
            categorical_feature=cat_features
        )
        
        preds = model.predict_proba(valid_x)[:, 1]
        auc = roc_auc_score(valid_y, preds)
        aucs.append(auc)
    
    return np.mean(aucs)

# %%
# Optuna를 사용한 하이퍼파라미터 최적화
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=500)
# Out:
# [I 2024-06-02 18:32:12,726] A new study created in memory with name: no-name-3ad7c798-d5f7-44a7-93c5-204bc5ec9b3b
# [I 2024-06-02 18:35:06,700] Trial 0 finished with value: 0.76512031372364 and parameters: {'num_leaves': 85, 'max_depth': 13, 'learning_rate': 0.028645948552580586, 'feature_fraction': 0.9168534977041871, 'bagging_fraction': 0.7955834197017922, 'bagging_freq': 7, 'min_child_samples': 15}. Best is trial 0 with value: 0.76512031372364.
# [I 2024-06-02 20:30:01,337] Trial 46 finished with value: 0.7746160991951234 and parameters: {'num_leaves': 142, 'max_depth': 14, 'learning_rate': 0.07732473203020292, 'feature_fraction': 0.6527517545835194, 'bagging_fraction': 0.809816120928848, 'bagging_freq': 7, 'min_child_samples': 84}. Best is trial 22 with value: 0.7746166823768227.
# [I 2024-06-02 20:32:48,180] Trial 47 finished with value: 0.7687789829724747 and parameters: {'num_leaves': 138, 'max_depth': 14, 'learning_rate': 0.03207002267826478, 'feature_fraction': 0.6488415011753382, 'bagging_fraction': 0.817475632871957, 'bagging_freq': 7, 'min_child_samples': 84}. Best is trial 22 with value: 0.7746166823768227.
# [I 2024-06-02 20:35:37,380] Trial 48 finished with value: 0.7437733026899951 and parameters: {'num_leaves': 117, 'max_depth': 14, 'learning_rate': 0.001058986392726613, 'feature_fraction': 0.6237649149952801, 'bagging_fraction': 0.8767403834160618, 'bagging_freq': 7, 'min_child_samples': 100}. Best is trial 22 with value: 0.7746166823768227.
# [I 2024-06-02 20:38:52,204] Trial 49 finished with value: 0.7723163791330881 and parameters: {'num_leaves': 148, 'max_depth': 15, 'learning_rate': 0.04496402474928788, 'feature_fraction': 0.9989569164405245, 'bagging_fraction': 0.8367533984356088, 'bagging_freq': 4, 'min_child_samples': 73}. Best is trial 22 with value: 0.7746166823768227.
# [I 2024-06-02 20:40:15,985] Trial 50 finished with value: 0.7319128238515467 and parameters: {'num_leaves': 100, 'max_depth': 5, 'learning_rate': 0.011994099826581622, 'feature_fraction': 0.6010802432258937, 'bagging_fraction': 0.8049033272918353, 'bagging_freq': 7, 'min_child_samples': 80}. Best is trial 22 with value: 0.7746166823768227.
# [I 2024-06-02 20:42:31,416] Trial 51 finished with value: 0.7738185757470597 and parameters: {'num_leaves': 154, 'max_depth': 13, 'learning_rate': 0.07518147489439789, 'feature_fraction': 0.6623827711672509, 'bagging_fraction': 0.7529861827069295, 'bagging_freq': 6, 'min_child_samples': 95}. Best is trial 22 with value: 0.7746166823768227.
# [I 2024-06-02 20:44:36,515] Trial 52 finished with value: 0.7732923542245247 and parameters: {'num_leaves': 136, 'max_depth': 12, 'learning_rate': 0.07975629351315976, 'feature_fraction': 0.6621631355218935, 'bagging_fraction': 0.7249506295961703, 'bagging_freq': 6, 'min_child_samples': 86}. Best is trial 22 with value: 0.7746166823768227.
# [I 2024-06-02 20:46:59,339] Trial 53 finished with value: 0.7738141329943382 and parameters: {'num_leaves': 153, 'max_depth': 13, 'learning_rate': 0.07737046519494427, 'feature_fraction': 0.8192219687734363, 'bagging_fraction': 0.7558021875148477, 'bagging_freq': 5, 'min_child_samples': 97}. Best is trial 22 with value: 0.7746166823768227.
# [I 2024-06-02 20:49:37,967] Trial 54 finished with value: 0.771786780317847 and parameters: {'num_leaves': 169, 'max_depth': 14, 'learning_rate': 0.04303867545411718, 'feature_fraction': 0.7283351725399158, 'bagging_fraction': 0.7055815598574202, 'bagging_freq': 6, 'min_child_samples': 90}. Best is trial 22 with value: 0.7746166823768227.
# [I 2024-06-02 20:51:42,549] Trial 55 finished with value: 0.7734632330315063 and parameters: {'num_leaves': 119, 'max_depth': 12, 'learning_rate': 0.07876904821858728, 'feature_fraction': 0.642391003033513, 'bagging_fraction': 0.7422373779429046, 'bagging_freq': 7, 'min_child_samples': 95}. Best is trial 22 with value: 0.7746166823768227.
# [I 2024-06-02 20:53:58,604] Trial 56 finished with value: 0.7718376696801104 and parameters: {'num_leaves': 70, 'max_depth': 15, 'learning_rate': 0.05170471576045479, 'feature_fraction': 0.7095038523145588, 'bagging_fraction': 0.6949846972490477, 'bagging_freq': 4, 'min_child_samples': 89}. Best is trial 22 with value: 0.7746166823768227.
# [I 2024-06-02 20:56:31,191] Trial 57 finished with value: 0.7628599433546388 and parameters: {'num_leaves': 131, 'max_depth': 11, 'learning_rate': 0.023311245642614182, 'feature_fraction': 0.6180667204251605, 'bagging_fraction': 0.80023915870439, 'bagging_freq': 3, 'min_child_samples': 100}. Best is trial 22 with value: 0.7746166823768227.
# [I 2024-06-02 20:58:47,021] Trial 58 finished with value: 0.7744639248236883 and parameters: {'num_leaves': 153, 'max_depth': 13, 'learning_rate': 0.09828346451651147, 'feature_fraction': 0.6689533770398439, 'bagging_fraction': 0.8584116103899815, 'bagging_freq': 6, 'min_child_samples': 84}. Best is trial 22 with value: 0.7746166823768227.
# [I 2024-06-02 21:01:16,770] Trial 59 finished with value: 0.7744630377474467 and parameters: {'num_leaves': 147, 'max_depth': 14, 'learning_rate': 0.09532481294177059, 'feature_fraction': 0.8472047007963579, 'bagging_fraction': 0.8367637934201524, 'bagging_freq': 5, 'min_child_samples': 77}. Best is trial 22 with value: 0.7746166823768227.
# [I 2024-06-02 21:04:34,825] Trial 60 finished with value: 0.7619413319156195 and parameters: {'num_leaves': 142, 'max_depth': 15, 'learning_rate': 0.018342880831584057, 'feature_fraction': 0.8551480922143124, 'bagging_fraction': 0.8327544899644639, 'bagging_freq': 5, 'min_child_samples': 76}. Best is trial 22 with value: 0.7746166823768227.
# [I 2024-06-02 21:07:08,796] Trial 61 finished with value: 0.7746606487127179 and parameters: {'num_leaves': 147, 'max_depth': 14, 'learning_rate': 0.0895514937802148, 'feature_fraction': 0.8450835651385009, 'bagging_fraction': 0.8571692982669721, 'bagging_freq': 5, 'min_child_samples': 85}. Best is trial 61 with value: 0.7746606487127179.
# [I 2024-06-02 21:09:41,866] Trial 62 finished with value: 0.774635546303953 and parameters: {'num_leaves': 150, 'max_depth': 14, 'learning_rate': 0.09970504581983194, 'feature_fraction': 0.8725990850672312, 'bagging_fraction': 0.859610113609564, 'bagging_freq': 5, 'min_child_samples': 83}. Best is trial 61 with value: 0.7746606487127179.
# [I 2024-06-02 21:12:49,779] Trial 63 finished with value: 0.7710355699668481 and parameters: {'num_leaves': 147, 'max_depth': 14, 'learning_rate': 0.04004553061052927, 'feature_fraction': 0.9282815742870053, 'bagging_fraction': 0.8598981623229207, 'bagging_freq': 5, 'min_child_samples': 84}. Best is trial 61 with value: 0.7746606487127179.
# [I 2024-06-02 21:15:34,755] Trial 64 finished with value: 0.7748943574772171 and parameters: {'num_leaves': 165, 'max_depth': 15, 'learning_rate': 0.09642666935161869, 'feature_fraction': 0.86591341663879, 'bagging_fraction': 0.8915761117886774, 'bagging_freq': 4, 'min_child_samples': 79}. Best is trial 64 with value: 0.7748943574772171.
# [I 2024-06-02 21:18:21,310] Trial 65 finished with value: 0.7750232568496962 and parameters: {'num_leaves': 165, 'max_depth': 15, 'learning_rate': 0.09282507787432148, 'feature_fraction': 0.8780406097854, 'bagging_fraction': 0.8906832935668991, 'bagging_freq': 4, 'min_child_samples': 70}. Best is trial 65 with value: 0.7750232568496962.
# [I 2024-06-02 21:21:27,916] Trial 66 finished with value: 0.7738770538251427 and parameters: {'num_leaves': 165, 'max_depth': 15, 'learning_rate': 0.05533418172608864, 'feature_fraction': 0.8718201632063729, 'bagging_fraction': 0.8917441302854268, 'bagging_freq': 4, 'min_child_samples': 69}. Best is trial 65 with value: 0.7750232568496962.
# [I 2024-06-02 21:24:24,795] Trial 67 finished with value: 0.7745032817618797 and parameters: {'num_leaves': 159, 'max_depth': 15, 'learning_rate': 0.0659108695623691, 'feature_fraction': 0.8984763039726512, 'bagging_fraction': 0.8611450347900257, 'bagging_freq': 3, 'min_child_samples': 81}. Best is trial 65 with value: 0.7750232568496962.
# [I 2024-06-02 21:27:59,824] Trial 68 finished with value: 0.7687869636910183 and parameters: {'num_leaves': 160, 'max_depth': 15, 'learning_rate': 0.029846344539018275, 'feature_fraction': 0.903643415735831, 'bagging_fraction': 0.918136072259785, 'bagging_freq': 3, 'min_child_samples': 80}. Best is trial 65 with value: 0.7750232568496962.
# [I 2024-06-02 21:30:58,883] Trial 69 finished with value: 0.7745234954028589 and parameters: {'num_leaves': 167, 'max_depth': 15, 'learning_rate': 0.066295517012228, 'feature_fraction': 0.8770739042909732, 'bagging_fraction': 0.888937797719812, 'bagging_freq': 2, 'min_child_samples': 72}. Best is trial 65 with value: 0.7750232568496962.
# [I 2024-06-02 21:34:42,677] Trial 70 finished with value: 0.751091686326685 and parameters: {'num_leaves': 167, 'max_depth': 15, 'learning_rate': 0.0072765483935213525, 'feature_fraction': 0.8800431523482405, 'bagging_fraction': 0.886119949284492, 'bagging_freq': 2, 'min_child_samples': 48}. Best is trial 65 with value: 0.7750232568496962.
# [I 2024-06-02 21:37:46,566] Trial 71 finished with value: 0.7743569263638108 and parameters: {'num_leaves': 158, 'max_depth': 15, 'learning_rate': 0.06462084975383456, 'feature_fraction': 0.9440992864148972, 'bagging_fraction': 0.8724482782814675, 'bagging_freq': 2, 'min_child_samples': 72}. Best is trial 65 with value: 0.7750232568496962.
# [I 2024-06-02 21:40:40,245] Trial 72 finished with value: 0.7750290051881712 and parameters: {'num_leaves': 176, 'max_depth': 15, 'learning_rate': 0.08420181262007125, 'feature_fraction': 0.9140208231483242, 'bagging_fraction': 0.9038526215221112, 'bagging_freq': 3, 'min_child_samples': 81}. Best is trial 72 with value: 0.7750290051881712.
# [I 2024-06-02 21:43:17,351] Trial 73 finished with value: 0.7749374988220813 and parameters: {'num_leaves': 175, 'max_depth': 15, 'learning_rate': 0.08348439981610986, 'feature_fraction': 0.9158690843937425, 'bagging_fraction': 0.9031610255087456, 'bagging_freq': 1, 'min_child_samples': 60}. Best is trial 72 with value: 0.7750290051881712.
# [I 2024-06-02 21:46:31,819] Trial 74 finished with value: 0.7728829150879697 and parameters: {'num_leaves': 176, 'max_depth': 14, 'learning_rate': 0.04921059342673665, 'feature_fraction': 0.9176412300415527, 'bagging_fraction': 0.9073790897358329, 'bagging_freq': 3, 'min_child_samples': 68}. Best is trial 72 with value: 0.7750290051881712.
# [I 2024-06-02 21:49:12,244] Trial 75 finished with value: 0.7746245437602665 and parameters: {'num_leaves': 193, 'max_depth': 14, 'learning_rate': 0.08365425031773506, 'feature_fraction': 0.9654616772685698, 'bagging_fraction': 0.9383497758112159, 'bagging_freq': 1, 'min_child_samples': 59}. Best is trial 72 with value: 0.7750290051881712.
# [I 2024-06-02 21:51:53,349] Trial 76 finished with value: 0.7748814587705866 and parameters: {'num_leaves': 194, 'max_depth': 15, 'learning_rate': 0.08487084152969712, 'feature_fraction': 0.9510493043839037, 'bagging_fraction': 0.9245303118615511, 'bagging_freq': 1, 'min_child_samples': 51}. Best is trial 72 with value: 0.7750290051881712.
# [I 2024-06-02 21:54:39,476] Trial 77 finished with value: 0.7748046139614847 and parameters: {'num_leaves': 194, 'max_depth': 15, 'learning_rate': 0.08312790346884676, 'feature_fraction': 0.9837892288517975, 'bagging_fraction': 0.937375210009053, 'bagging_freq': 1, 'min_child_samples': 44}. Best is trial 72 with value: 0.7750290051881712.
# [I 2024-06-02 21:58:03,213] Trial 78 finished with value: 0.7715795714925588 and parameters: {'num_leaves': 183, 'max_depth': 15, 'learning_rate': 0.03912658692494312, 'feature_fraction': 0.9645504520488942, 'bagging_fraction': 0.9178188211007138, 'bagging_freq': 1, 'min_child_samples': 44}. Best is trial 72 with value: 0.7750290051881712.
# [I 2024-06-02 22:01:04,208] Trial 79 finished with value: 0.773864243703555 and parameters: {'num_leaves': 174, 'max_depth': 15, 'learning_rate': 0.05437022134783022, 'feature_fraction': 0.9542307309305688, 'bagging_fraction': 0.9210873189475629, 'bagging_freq': 1, 'min_child_samples': 38}. Best is trial 72 with value: 0.7750290051881712.
# [I 2024-06-02 22:02:21,265] Trial 80 finished with value: 0.7567843075430989 and parameters: {'num_leaves': 194, 'max_depth': 4, 'learning_rate': 0.08935310563781892, 'feature_fraction': 0.9843622816938571, 'bagging_fraction': 0.945803220750421, 'bagging_freq': 1, 'min_child_samples': 50}. Best is trial 72 with value: 0.7750290051881712.
# [I 2024-06-02 22:04:58,554] Trial 81 finished with value: 0.7748661645776107 and parameters: {'num_leaves': 178, 'max_depth': 15, 'learning_rate': 0.0856344295329762, 'feature_fraction': 0.9108991982725492, 'bagging_fraction': 0.9065256739081892, 'bagging_freq': 1, 'min_child_samples': 59}. Best is trial 72 with value: 0.7750290051881712.
# [I 2024-06-02 22:08:40,105] Trial 82 finished with value: 0.7448408747101858 and parameters: {'num_leaves': 180, 'max_depth': 15, 'learning_rate': 0.002912025389897724, 'feature_fraction': 0.8904758587926308, 'bagging_fraction': 0.9038623464566362, 'bagging_freq': 1, 'min_child_samples': 41}. Best is trial 72 with value: 0.7750290051881712.
# [I 2024-06-02 22:11:16,657] Trial 83 finished with value: 0.7748352987400382 and parameters: {'num_leaves': 186, 'max_depth': 15, 'learning_rate': 0.08361789222497704, 'feature_fraction': 0.9132176730982324, 'bagging_fraction': 0.8709250308911428, 'bagging_freq': 1, 'min_child_samples': 55}. Best is trial 72 with value: 0.7750290051881712.
# [I 2024-06-02 22:14:14,523] Trial 84 finished with value: 0.7741497644737756 and parameters: {'num_leaves': 178, 'max_depth': 15, 'learning_rate': 0.058475741658982686, 'feature_fraction': 0.924410299113031, 'bagging_fraction': 0.9317278242303536, 'bagging_freq': 1, 'min_child_samples': 52}. Best is trial 72 with value: 0.7750290051881712.
# [I 2024-06-02 22:17:39,804] Trial 85 finished with value: 0.7725982831148286 and parameters: {'num_leaves': 184, 'max_depth': 15, 'learning_rate': 0.044640830298207534, 'feature_fraction': 0.9105976440191439, 'bagging_fraction': 0.8722701992174351, 'bagging_freq': 2, 'min_child_samples': 57}. Best is trial 72 with value: 0.7750290051881712.
# [I 2024-06-02 22:20:15,812] Trial 86 finished with value: 0.7749521070159368 and parameters: {'num_leaves': 187, 'max_depth': 15, 'learning_rate': 0.08582345342380515, 'feature_fraction': 0.910035923724512, 'bagging_fraction': 0.895161611475581, 'bagging_freq': 1, 'min_child_samples': 62}. Best is trial 72 with value: 0.7750290051881712.
# [I 2024-06-02 22:22:19,262] Trial 87 finished with value: 0.7096784085097848 and parameters: {'num_leaves': 186, 'max_depth': 7, 'learning_rate': 0.00012030566507634103, 'feature_fraction': 0.942125231638138, 'bagging_fraction': 0.9115800878914216, 'bagging_freq': 1, 'min_child_samples': 61}. Best is trial 72 with value: 0.7750290051881712.
# [I 2024-06-02 22:25:01,209] Trial 88 finished with value: 0.7748373953414737 and parameters: {'num_leaves': 193, 'max_depth': 15, 'learning_rate': 0.08023006490549779, 'feature_fraction': 0.9298113305918088, 'bagging_fraction': 0.8932876600319907, 'bagging_freq': 1, 'min_child_samples': 64}. Best is trial 72 with value: 0.7750290051881712.
# [I 2024-06-02 22:28:35,795] Trial 89 finished with value: 0.7702465783446681 and parameters: {'num_leaves': 172, 'max_depth': 15, 'learning_rate': 0.03401614417801935, 'feature_fraction': 0.9316371480167344, 'bagging_fraction': 0.8968784158543457, 'bagging_freq': 2, 'min_child_samples': 64}. Best is trial 72 with value: 0.7750290051881712.
# [I 2024-06-02 22:31:20,036] Trial 90 finished with value: 0.7747177205773838 and parameters: {'num_leaves': 189, 'max_depth': 15, 'learning_rate': 0.06961359416351232, 'feature_fraction': 0.9091370009252135, 'bagging_fraction': 0.883372297186573, 'bagging_freq': 1, 'min_child_samples': 54}. Best is trial 72 with value: 0.7750290051881712.
# [I 2024-06-02 22:34:03,704] Trial 91 finished with value: 0.7749663395990687 and parameters: {'num_leaves': 195, 'max_depth': 15, 'learning_rate': 0.08093460551359825, 'feature_fraction': 0.887553204107058, 'bagging_fraction': 0.9489605514693862, 'bagging_freq': 1, 'min_child_samples': 58}. Best is trial 72 with value: 0.7750290051881712.
# [I 2024-06-02 22:37:02,292] Trial 92 finished with value: 0.7737646511203331 and parameters: {'num_leaves': 200, 'max_depth': 14, 'learning_rate': 0.05701155323149326, 'feature_fraction': 0.9171313127112295, 'bagging_fraction': 0.9512872815099482, 'bagging_freq': 1, 'min_child_samples': 59}. Best is trial 72 with value: 0.7750290051881712.
# [I 2024-06-02 22:39:43,065] Trial 93 finished with value: 0.7748438518178383 and parameters: {'num_leaves': 194, 'max_depth': 15, 'learning_rate': 0.08028714994869607, 'feature_fraction': 0.886806263945314, 'bagging_fraction': 0.9094141584391607, 'bagging_freq': 1, 'min_child_samples': 62}. Best is trial 72 with value: 0.7750290051881712.
# [I 2024-06-02 22:42:30,965] Trial 94 finished with value: 0.774625332763023 and parameters: {'num_leaves': 191, 'max_depth': 15, 'learning_rate': 0.06850276379142144, 'feature_fraction': 0.8878874015527205, 'bagging_fraction': 0.8955062195077953, 'bagging_freq': 1, 'min_child_samples': 66}. Best is trial 72 with value: 0.7750290051881712.
# [I 2024-06-02 22:45:32,120] Trial 95 finished with value: 0.7732610337374854 and parameters: {'num_leaves': 196, 'max_depth': 14, 'learning_rate': 0.0501560347845755, 'feature_fraction': 0.8662765108413816, 'bagging_fraction': 0.9683188366776839, 'bagging_freq': 1, 'min_child_samples': 62}. Best is trial 72 with value: 0.7750290051881712.
# [I 2024-06-02 22:48:36,547] Trial 96 finished with value: 0.7749482950239859 and parameters: {'num_leaves': 178, 'max_depth': 15, 'learning_rate': 0.07796168050109124, 'feature_fraction': 0.9511514595379493, 'bagging_fraction': 0.9131059951970388, 'bagging_freq': 2, 'min_child_samples': 57}. Best is trial 72 with value: 0.7750290051881712.
# [I 2024-06-02 22:51:22,744] Trial 97 finished with value: 0.7740904272682501 and parameters: {'num_leaves': 177, 'max_depth': 14, 'learning_rate': 0.06439159847628977, 'feature_fraction': 0.9568051993068671, 'bagging_fraction': 0.9104108621192497, 'bagging_freq': 1, 'min_child_samples': 51}. Best is trial 72 with value: 0.7750290051881712.
# [I 2024-06-02 22:54:51,733] Trial 98 finished with value: 0.7722635396154492 and parameters: {'num_leaves': 170, 'max_depth': 15, 'learning_rate': 0.04130886701409442, 'feature_fraction': 0.9031731551338602, 'bagging_fraction': 0.9187382804392391, 'bagging_freq': 2, 'min_child_samples': 57}. Best is trial 72 with value: 0.7750290051881712.
# [I 2024-06-02 22:57:47,573] Trial 99 finished with value: 0.774656635517582 and parameters: {'num_leaves': 163, 'max_depth': 14, 'learning_rate': 0.0746438748755762, 'feature_fraction': 0.8854180898463098, 'bagging_fraction': 0.9276578226333234, 'bagging_freq': 2, 'min_child_samples': 62}. Best is trial 72 with value: 0.7750290051881712.
# [I 2024-06-02 23:00:34,301] Trial 100 finished with value: 0.7750652741081963 and parameters: {'num_leaves': 179, 'max_depth': 15, 'learning_rate': 0.09989342865651249, 'feature_fraction': 0.8639466305783383, 'bagging_fraction': 0.9393984653126447, 'bagging_freq': 4, 'min_child_samples': 59}. Best is trial 100 with value: 0.7750652741081963.
# [I 2024-06-02 23:03:32,884] Trial 101 finished with value: 0.775026405118677 and parameters: {'num_leaves': 181, 'max_depth': 15, 'learning_rate': 0.087247274766646, 'feature_fraction': 0.8960052045772011, 'bagging_fraction': 0.9463347049944921, 'bagging_freq': 4, 'min_child_samples': 58}. Best is trial 100 with value: 0.7750652741081963.
# [I 2024-06-02 23:06:26,366] Trial 102 finished with value: 0.7748848611473866 and parameters: {'num_leaves': 180, 'max_depth': 15, 'learning_rate': 0.09692760916640658, 'feature_fraction': 0.8960460336480608, 'bagging_fraction': 0.9414835944618181, 'bagging_freq': 4, 'min_child_samples': 60}. Best is trial 100 with value: 0.7750652741081963.
# [I 2024-06-02 23:09:34,777] Trial 103 finished with value: 0.7740165475412135 and parameters: {'num_leaves': 183, 'max_depth': 14, 'learning_rate': 0.05924110532308371, 'feature_fraction': 0.8601574144270621, 'bagging_fraction': 0.9610308717629079, 'bagging_freq': 4, 'min_child_samples': 53}. Best is trial 100 with value: 0.7750652741081963.
# [I 2024-06-02 23:12:28,942] Trial 104 finished with value: 0.7751748697344423 and parameters: {'num_leaves': 181, 'max_depth': 15, 'learning_rate': 0.09180953322134973, 'feature_fraction': 0.8234848139711167, 'bagging_fraction': 0.938863452490163, 'bagging_freq': 4, 'min_child_samples': 67}. Best is trial 104 with value: 0.7751748697344423.
# [I 2024-06-02 23:16:23,380] Trial 105 finished with value: 0.7420470996593171 and parameters: {'num_leaves': 172, 'max_depth': 15, 'learning_rate': 0.0014571078190444094, 'feature_fraction': 0.842871834338439, 'bagging_fraction': 0.9504301979773799, 'bagging_freq': 4, 'min_child_samples': 59}. Best is trial 104 with value: 0.7751748697344423.
# [I 2024-06-02 23:19:34,282] Trial 106 finished with value: 0.7730703891427276 and parameters: {'num_leaves': 175, 'max_depth': 14, 'learning_rate': 0.04830677273838156, 'feature_fraction': 0.815699864410043, 'bagging_fraction': 0.9405892222092379, 'bagging_freq': 4, 'min_child_samples': 71}. Best is trial 104 with value: 0.7751748697344423.
# [I 2024-06-02 23:22:25,348] Trial 107 finished with value: 0.7749016030884495 and parameters: {'num_leaves': 181, 'max_depth': 14, 'learning_rate': 0.09611203273523214, 'feature_fraction': 0.895808968714476, 'bagging_fraction': 0.9747386957883111, 'bagging_freq': 4, 'min_child_samples': 68}. Best is trial 104 with value: 0.7751748697344423.
# [I 2024-06-02 23:25:28,993] Trial 108 finished with value: 0.7745805385697727 and parameters: {'num_leaves': 187, 'max_depth': 14, 'learning_rate': 0.06989710237139653, 'feature_fraction': 0.8625698975204793, 'bagging_fraction': 0.9706686784623605, 'bagging_freq': 4, 'min_child_samples': 67}. Best is trial 104 with value: 0.7751748697344423.
# [I 2024-06-02 23:28:17,987] Trial 109 finished with value: 0.77531928179495 and parameters: {'num_leaves': 163, 'max_depth': 15, 'learning_rate': 0.09945298574259205, 'feature_fraction': 0.8361216459135137, 'bagging_fraction': 0.9835708168395957, 'bagging_freq': 4, 'min_child_samples': 23}. Best is trial 109 with value: 0.77531928179495.
# [I 2024-06-02 23:31:03,664] Trial 110 finished with value: 0.7751198684005739 and parameters: {'num_leaves': 169, 'max_depth': 14, 'learning_rate': 0.09986037938350145, 'feature_fraction': 0.8286193002693609, 'bagging_fraction': 0.9894086798972501, 'bagging_freq': 3, 'min_child_samples': 24}. Best is trial 109 with value: 0.77531928179495.
# [I 2024-06-02 23:33:58,978] Trial 111 finished with value: 0.7748102756756046 and parameters: {'num_leaves': 162, 'max_depth': 14, 'learning_rate': 0.07342795033130195, 'feature_fraction': 0.8309471899600989, 'bagging_fraction': 0.9875264610594646, 'bagging_freq': 3, 'min_child_samples': 21}. Best is trial 109 with value: 0.77531928179495.

# %%
# 최적 하이퍼파라미터로 모델 훈련
best_params = study.best_params
model = lgb.LGBMClassifier(**best_params)
model.fit(df.drop('Click', axis=1), df['Click'], categorical_feature=cat_features)

# %%
# 테스트 데이터 불러오기 및 전처리
def load_data():
    df = pd.read_csv('test.csv')
    df = df.drop('ID', axis=1)
    fill_cols = ['F04', 'F11', 'F18', 'F19', 'F24', 'F27', 'F29', 'F32', 'F33', 'F36', 'F38']
    df[fill_cols] = df[fill_cols].fillna(0)
    df = df.fillna('NAN')
    float_columns = df.select_dtypes(include=['float64']).columns
    df[float_columns] = df[float_columns].astype('int64')
    object_columns = df.select_dtypes(include=['object']).columns
    df[object_columns] = df[object_columns].astype('category')
    
    # 테스트 데이터의 범주형 피처를 학습 데이터와 동일하게 설정
    for col in cat_features:
        if col in df.columns:
            df[col] = df[col].astype('category')
            df[col] = df[col].cat.set_categories(df[col].cat.categories)
        else:
            df[col] = pd.Categorical([None] * len(df), categories=df[col].cat.categories)
    
    # 표준화
    scaled_features = scaler.transform(df.select_dtypes(include=[np.number]))
    scaled_df = pd.DataFrame(scaled_features, columns=df.select_dtypes(include=[np.number]).columns)
    df.update(scaled_df)
    
    return df

test_df = load_data()

# %%
# 테스트 데이터 예측
pred = model.predict_proba(test_df)

# %%
# 결과 저장
sample_submission = pd.read_csv('sample_submission.csv')
sample_submission['Click'] = pred[:, 1]
sample_submission.to_csv('lgbm_optuna.csv', index=False)
